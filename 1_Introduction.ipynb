# %% [markdown]
# # Introduction : datasets et visualisation

# %% [markdown]
# ## Importations des librairies courantes

# %%
# Pandas : librairie de manipulation de données
# NumPy : librairie de calcul scientifique
# MatPlotLib : librairie de visualisation et graphiques
# SeaBorn : librairie de graphiques avancés
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# Directive pour afficher les graphiques dans Jupyter
# %matplotlib inline

# %% [markdown]
# # Exemple : Maisons à Boston

# %% [markdown]
# ## Lecture du fichier

# %%
# Sous windows, le fichier peut être dans le répertoire "Documents"
bos=pd.read_csv("boston.csv")
# On peut aussi iniquer le chemin d'accès, avec le séparateur '/' (même sous Windows)
# par exemple t=pd.read_csv("C:/datas/boston.csv")
# le séparateur par défaut est la virgule

# %%
# Alternative : utilisation du dataset préfini dans sklearn

from sklearn.datasets import load_boston

boston = load_boston()
# On transforme le tableau en dataframe
bos = pd.DataFrame(boston.data, columns=boston.feature_names)
# On ajoute la colonne 'MV', qui est un tableau séparé dans le dataset sklearn (target)
bos['MV'] = boston.target

# %% [markdown]
# ## Dataframe

# %% [markdown]
# Le fichier est lu sous la forme d'un **Dataframe**
#
# Un Dataframe est une table dont les colonnes sont nommées. Les colonnes d'un Dataframe sont des séries (des vecteurs pour simplifier)

# %%
# Visualisation du début du dataframe
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.199997  4.0900    1  296
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.900002  4.9671    2  242
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.099998  4.9671    2  242
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.799999  6.0622    3  222
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.200001  6.0622    3  222
#
#           PT           B  LSTAT         MV
# 0  15.300000  396.899994   4.98  24.000000
# 1  17.799999  396.899994   9.14  21.600000
# 2  17.799999  392.829987   4.03  34.700001
# 3  18.700001  394.630005   2.94  33.400002
# 4  18.700001  396.899994   5.33  36.200001

# %%
# Fin du Dataframe
bos.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.099998  2.4786    1  273
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.699997  2.2875    1  273
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.300003  2.3889    1  273
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.800003  2.5050    1  273
#
#        PT           B  LSTAT    MV
# 501  21.0  391.989990   9.67  22.4
# 502  21.0  396.899994   9.08  20.6
# 503  21.0  396.899994   5.64  23.9
# 504  21.0  393.450012   6.48  22.0
# 505  21.0  396.899994   7.88  11.9

# %% [markdown]
# ### Interprétation des colonnes

# %% [raw]
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT - % lower status of the population
# MV - Median value of owner-occupied homes in $1000's

# %%
# Une colonne de la table
bos['MV']
# Out:
# 0      24.000000
# 1      21.600000
# 2      34.700001
# 3      33.400002
# 4      36.200001
# 5      28.700001
# 6      22.900000
# 7      27.100000
# 8      16.500000
# 9      18.900000
# 10     15.000000
# 11     18.900000
# 12     21.700001
# 13     20.400000
# 14     18.200001
# 15     19.900000
# 16     23.100000
# 17     17.500000
# 18     20.200001
# 19     18.200001
# 20     13.600000
# 21     19.600000
# 22     15.200000
# 23     14.500000
# 24     15.600000
# 25     13.900000
# 26     16.600000
# 27     14.800000
# 28     18.400000
# 29     21.000000
#          ...
# 476    16.700001
# 477    12.000000
# 478    14.600000
# 479    21.400000
# 480    23.000000
# 481    23.700001
# 482    25.000000
# 483    21.799999
# 484    20.600000
# 485    21.200001
# 486    19.100000
# 487    20.600000
# 488    15.200000
# 489     7.000000
# 490     8.100000
# 491    13.600000
# 492    20.100000
# 493    21.799999
# 494    24.500000
# 495    23.100000
# 496    19.700001
# 497    18.299999
# 498    21.200001
# 499    17.500000
# 500    16.799999
# 501    22.400000
# 502    20.600000
# 503    23.900000
# 504    22.000000
# 505    11.900000
# Name: MV, Length: 506, dtype: float64

# %%
# Ou une notation équivalente sous forme pointée (si les colonnes sont des identifiants simples)
bos.MV
# Out:
# 0      24.000000
# 1      21.600000
# 2      34.700001
# 3      33.400002
# 4      36.200001
# 5      28.700001
# 6      22.900000
# 7      27.100000
# 8      16.500000
# 9      18.900000
# 10     15.000000
# 11     18.900000
# 12     21.700001
# 13     20.400000
# 14     18.200001
# 15     19.900000
# 16     23.100000
# 17     17.500000
# 18     20.200001
# 19     18.200001
# 20     13.600000
# 21     19.600000
# 22     15.200000
# 23     14.500000
# 24     15.600000
# 25     13.900000
# 26     16.600000
# 27     14.800000
# 28     18.400000
# 29     21.000000
#          ...
# 476    16.700001
# 477    12.000000
# 478    14.600000
# 479    21.400000
# 480    23.000000
# 481    23.700001
# 482    25.000000
# 483    21.799999
# 484    20.600000
# 485    21.200001
# 486    19.100000
# 487    20.600000
# 488    15.200000
# 489     7.000000
# 490     8.100000
# 491    13.600000
# 492    20.100000
# 493    21.799999
# 494    24.500000
# 495    23.100000
# 496    19.700001
# 497    18.299999
# 498    21.200001
# 499    17.500000
# 500    16.799999
# 501    22.400000
# 502    20.600000
# 503    23.900000
# 504    22.000000
# 505    11.900000
# Name: MV, Length: 506, dtype: float64

# %%
# On peut appliquer les opérations usuelles sur les séries

# lignes entre 50 et 55
print(bos.MV[50:55])

# Valeurs min, max, moyenne, ecart type, quantiles
print(bos.MV.min())
print(bos.MV.max())
print(bos.MV.mean())
print(bos.MV.std())
print(np.percentile(bos.MV,[0,25,50,75,100]))
# Out:
# 50    19.700001
# 51    20.500000
# 52    25.000000
# 53    23.400000
# 54    18.900000
# Name: MV, dtype: float64
# 5.0
# 50.0
# 22.53280636250988
# 9.197104107945279
# [  5.          17.02500009  21.20000076  25.          50.        ]

# %% [markdown]
# ## Opération sur le Dataframe

# %%
# Dimensions de la table
bos.shape
# Out:
# (506, 14)

# %%
# Informations sur les types des données
bos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM     506 non-null float64
# ZN       506 non-null float64
# INDUS    506 non-null float64
# CHAS     506 non-null int64
# NOX      506 non-null float64
# RM       506 non-null float64
# AGE      506 non-null float64
# DIS      506 non-null float64
# RAD      506 non-null int64
# TAX      506 non-null int64
# PT       506 non-null float64
# B        506 non-null float64
# LSTAT    506 non-null float64
# MV       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.4 KB

# %%
# Statistiques sur la table
bos.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976196  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TA
# 155  14.700000   88.010002  15.020000  15.600000
# 160  14.700000  338.920013   5.500000  27.000000
# 162  14.700000  389.609985   1.920000  50.000000
# 163  14.700000  388.450012   3.320000  50.000000
# 208  18.600000  381.320007  14.660000  24.400000
# 209  18.600000  396.899994  23.090000  20.000000
# 210  18.600000  393.250000  17.270000  21.700001
# 211  18.600000  395.239990  23.980000  19.299999
# 212  18.600000  390.940002  16.030001  22.400000
# 216  16.400000  392.799988  13.510000  23.299999
# 218  16.400000  396.899994  17.920000  21.500000
# 219  16.400000  393.739990  10.500000  23.000000
# 220  17.400000  391.700012   9.710000  26.700001
# 221  17.400000  395.239990  21.459999  21.700001
# 222  17.400000  390.390015   9.930000  27.500000
# 234  17.400000  360.200012   8.050000  29.000000
# 236  17.400000  388.450012   9.540000  25.100000
# 269  18.600000  391.339996  13.650000  20.700001
# 273  18.600000  390.769989   6.580000  35.200001
# 274  17.600000  396.899994   3.530000  32.400002
# 276  17.600000  389.250000   6.050000  33.200001
# 277  17.600000  393.450012   4.160000  33.099998
# 282  14.900000  377.070007   3.010000  46.000000
# 283  13.600000  395.519989   3.160000  50.000000
# 356  20.200001  377.730011  17.600000  17.799999
# 357  20.200001  391.339996  13.270000  21.700001
# 358  20.200001  395.429993  11.480000  22.700001
# 363  20.200001  353.040008  14.640000  16.799999
# 364  20.200001  354.549988   5.290000  21.900000
# 369  20.200001  375.329987   3.730000  50.000000
# 370  20.200001  392.049988   2.960000  50.000000
# 372  20.200001  347.880005   8.880000  50.000000

# %%
# On peut compter le nombre de valeurs, par exemple les maisons près de la rivière ou pas
bos.CHAS.value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
# Suppression de colonnes, par exemple la colonne CHAS qui ne contient que des valeurs 0 ou 1
# axis=1 pour supprimer des colonnes, axis=0 pour des lignes
bos = bos.drop(['CHAS'], axis=1)

# %%
bos.head()
# Out:
#       CRIM    ZN  INDUS    NOX     RM        AGE     DIS  RAD  TAX         PT  \
# 0  0.00632  18.0   2.31  0.538  6.575  65.199997  4.0900    1  296  15.300000
# 1  0.02731   0.0   7.07  0.469  6.421  78.900002  4.9671    2  242  17.799999
# 2  0.02729   0.0   7.07  0.469  7.185  61.099998  4.9671    2  242  17.799999
# 3  0.03237   0.0   2.18  0.458  6.998  45.799999  6.0622    3  222  18.700001
# 4  0.06905   0.0   2.18  0.458  7.147  54.200001  6.0622    3  222  18.700001
#
#             B  LSTAT         MV
# 0  396.899994   4.98  24.000000
# 1  396.899994   9.14  21.600000
# 2  392.829987   4.03  34.700001
# 3  394.630005   2.94  33.400002
# 4  396.899994   5.33  36.200001

# %% [markdown]
#
# ** Pour plus de détails sur Pandas et la manipulation de Dataframes :
# https://github.com/jhroy/tuto-pandas/blob/master/tutoriel.ipynb
# https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python  **

# %% [markdown]
# ## Graphiques simples

# %% [markdown]
# On veut afficher le nuage des points (nombre de pieces, valeur)

# %%
plt.figure(figsize=(12,12))                 # Dimensions de la figure
plt.plot(bos.RM, bos.MV,'b.')               # l'option'bo' affiche des ronds bleus
                                            # on peut utiliser 'r.' pour des points rouges, etc ...
# on peut aussi utiliser les graphiques de type "scatter" (similaire) :
# plt.scatter(bos.RM, bos.MV, color='blue')
plt.xlabel('Nb de pieces')                  # Etiquette pour l'axe Ox
plt.ylabel('Valeur')                        # Etiquette pour l'axe Oy
plt.title('Valeur par nb de pieces')        # Titre du graphique
# Out:
# Text(0.5,1,'Valeur par nb de pieces')

# %% [markdown]
# On observe une correlation entre les deux paramètres, ce qui semble logique.
# Par ailleurs, on voit plusieurs points correspondant à la valeur maximum 50, qui semblent mal placés ...
# On va le vérifier sur un histogramme

# %%
plt.figure(figsize=(12,6))                 
plt.hist(bos.RM, color='blue', bins=100)      # les "bins" représentent le nombre de barres de l'histogramme
plt.xlabel('Nb de pieces')                  
plt.ylabel('Valeur')                        
plt.title('Valeur par nb de pieces')      
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# On constate en effet un pic inhabituel pour la valeur 50.
# On sélectionne les lignes dont la valeur est 50 :

# %%
bos[bos.MV == 50]
# Out:
#         CRIM    ZN  INDUS     NOX     RM         AGE     DIS  RAD  TAX  \
# 161  1.46336   0.0  19.58  0.6050  7.489   90.800003  1.9709    5  403
# 162  1.83377   0.0  19.58  0.6050  7.802   98.199997  2.0407    5  403
# 163  1.51902   0.0  19.58  0.6050  8.375   93.900002  2.1620    5  403
# 166  2.01019   0.0  19.58  0.6050  7.929   96.199997  2.0459    5  403
# 186  0.05602   0.0   2.46  0.4880  7.831   53.599998  3.1992    3  193
# 195  0.01381  80.0   0.46  0.4220  7.875   32.000000  5.6484    4  255
# 204  0.02009  95.0   2.68  0.4161  8.034   31.900000  5.1180    4  224
# 225  0.52693   0.0   6.20  0.5040  8.725   83.000000  2.8944    8  307
# 257  0.61154  20.0   3.97  0.6470  8.704   86.900002  1.8010    5  264
# 267  0.57834  20.0   3.97  0.5750  8.297   67.000000  2.4216    5  264
# 283  0.01501  90.0   1.21  0.4010  7.923   24.799999  5.8850    1  198
# 368  4.89822   0.0  18.10  0.6310  4.970  100.000000  1.3325   24  666
# 369  5.66998   0.0  18.10  0.6310  6.683   96.800003  1.3567   24  666
# 370  6.53876   0.0  18.10  0.6310  7.016   97.500000  1.2024   24  666
# 371  9.23230   0.0  18.10  0.6310  6.216  100.000000  1.1691   24  666
# 372  8.26725   0.0  18.10  0.6680  5.875   89.599998  1.1296   24  666
#
#             PT           B  LSTAT    MV
# 161  14.700000  374.429993   1.73  50.0
# 162  14.700000  389.609985   1.92  50.0
# 163  14.700000  388.450012   3.32  50.0
# 166  14.700000  369.299988   3.70  50.0
# 186  17.799999  392.630005   4.45  50.0
# 195  14.400000  394.230011   2.97  50.0
# 204  14.700000  390.549988   2.88  50.0
# 225  17.400000  382.000000   4.63  50.0
# 257  13.000000  389.700012   5.12  50.0
# 267  13.000000  384.540008   7.44  50.0
# 283  13.600000  395.519989   3.16  50.0
# 368  20.200001  375.519989   3.26  50.0
# 369  20.200001  375.329987   3.73  50.0
# 370  20.200001  392.049988   2.96  50.0
# 371  20.200001  366.149994   9.53  50.0
# 372  20.200001  347.880005   8.88  50.0

# %% [markdown]
# On a 16 lignes :

# %%
bos[bos.MV == 50].count()
# Out:
# CRIM     16
# ZN       16
# INDUS    16
# NOX      16
# RM       16
# AGE      16
# DIS      16
# RAD      16
# TAX      16
# PT       16
# B        16
# LSTAT    16
# MV       16
# dtype: int64

# %% [markdown]
# Il semble raisonnable d'éliminer ces lignes afin de ne pas pertuber l'analyse avec des valeurs manifestement erronées :

# %%
bos = bos[bos.MV != 50]         # On conserve les lignes pour lesquelles MV est différent de 50

# %%
plt.figure(figsize=(12,6))                 
plt.hist(bos.MV, color='blue', bins=100)      
plt.xlabel('Nb de pieces')                  
plt.ylabel('Valeur')                        
plt.title('Valeur par nb de pieces')      
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
#
# ** Il existe une multitude d'options, de types de graphiques et de mises en forme.
# Pour plus de détails sur les graphiques et le module matplotlib :
# http://www.python-simple.com/python-matplotlib/matplotlib-intro.php **

# %% [markdown]
# ## Recherche de corrélations

# %% [markdown]
# On a vu assez clairement la corrélation entre le nombre de pièces et la valeur.
# On va utiliser la fonction *corr* pour calculer systématiquement le degré de corrélation entre deux paramètres :

# %%
tabcorr = bos.corr()     # on peut utiliser aussi bos.corr(method='pearson') par exemple
print(tabcorr)
# Out:
#            CRIM        ZN     INDUS       NOX        RM       AGE       DIS  \
# CRIM   1.000000 -0.199075  0.408053  0.420476 -0.219307  0.353751 -0.382231
# ZN    -0.199075  1.000000 -0.527121 -0.512137  0.310506 -0.563184  0.673227
# INDUS  0.408053 -0.527121  1.000000  0.765155 -0.412413  0.637970 -0.710284
# NOX    0.420476 -0.512137  0.765155  1.000000 -0.322609  0.727671 -0.768122
# RM    -0.219307  0.310506 -0.412413 -0.322609  1.000000 -0.268464  0.245789
# AGE    0.353751 -0.563184  0.637970  0.727671 -0.268464  1.000000 -0.743043
# DIS   -0.382231  0.673227 -0.710284 -0.768122  0.245789 -0.743043  1.000000
# RAD    0.627434 -0.307726  0.596124  0.612160 -0.195768  0.451939 -0.491875
# TAX    0.583711 -0.302897  0.717678  0.667380 -0.281955  0.499682 -0.532025
# PT     0.287079 -0.381815  0.387657  0.188381 -0.293299  0.268459 -0.246773
# B     -0.384460  0.176117 -0.363394 -0.383087  0.119204 -0.279002  0.299426
# LSTAT  0.461755 -0.422090  0.636527  0.612444 -0.610369  0.637879 -0.536493
# MV    -0.450115  0.404608 -0.600005 -0.524451  0.686634 -0.492915  0.368813
#
#             RAD       TAX        PT         B     LSTAT        MV
# CRIM   0.627434  0.583711  0.287079 -0.384460  0.461755 -0.450115
# ZN    -0.307726 -0.302897 -0.381815  0.176117 -0.422090  0.404608
# INDUS  0.596124  0.717678  0.387657 -0.363394  0.636527 -0.600005
# NOX    0.612160  0.667380  0.188381 -0.383087  0.612444 -0.524451
# RM    -0.195768 -0.281955 -0.293299  0.119204 -0.610369  0.686634
# AGE    0.451939  0.499682  0.268459 -0.279002  0.637879 -0.492915
# DIS   -0.491875 -0.532025 -0.246773  0.299426 -0.536493  0.368813
# RAD    1.000000  0.909000  0.456035 -0.451534  0.510192 -0.476296
# TAX    0.909000  1.000000  0.452252 -0.448211  0.566467 -0.572442
# PT     0.456035  0.452252  1.000000 -0.173636  0.358024 -0.518641
# B     -0.451534 -0.448211 -0.173636  1.000000 -0.364099  0.364928
# LSTAT  0.510192  0.566467  0.358024 -0.364099  1.000000 -0.759837
# MV    -0.476296 -0.572442 -0.518641  0.364928 -0.759837  1.000000

# %% [markdown]
# On s'intéresse plus précisément à la valeur des maisons :

# %%
correlations = tabcorr.MV
print(correlations)
# Out:
# CRIM    -0.450115
# ZN       0.404608
# INDUS   -0.600005
# NOX     -0.524451
# RM       0.686634
# AGE     -0.492915
# DIS      0.368813
# RAD     -0.476296
# TAX     -0.572442
# PT      -0.518641
# B        0.364928
# LSTAT   -0.759837
# MV       1.000000
# Name: MV, dtype: float64

# %% [markdown]
# On élimine la ligne MV elle-même (qui est forcément à 1) :

# %%
correlations = correlations.drop(['MV'],axis=0)
print(correlations)
# Out:
# CRIM    -0.450115
# ZN       0.404608
# INDUS   -0.600005
# NOX     -0.524451
# RM       0.686634
# AGE     -0.492915
# DIS      0.368813
# RAD     -0.476296
# TAX     -0.572442
# PT      -0.518641
# B        0.364928
# LSTAT   -0.759837
# Name: MV, dtype: float64

# %% [markdown]
# Les corrélations fortement négatives sont aussi significatives que les positives ; on considère donc les valeurs absolues :

# %%
correlations = abs(correlations)
print(correlations)
# Out:
# CRIM     0.450115
# ZN       0.404608
# INDUS    0.600005
# NOX      0.524451
# RM       0.686634
# AGE      0.492915
# DIS      0.368813
# RAD      0.476296
# TAX      0.572442
# PT       0.518641
# B        0.364928
# LSTAT    0.759837
# Name: MV, dtype: float64

# %%
correlations = correlations.sort_values(ascending=False)     # Tri par ordre décroissant
print(correlations)
# Out:
# LSTAT    0.759837
# RM       0.686634
# INDUS    0.600005
# TAX      0.572442
# NOX      0.524451
# PT       0.518641
# AGE      0.492915
# RAD      0.476296
# CRIM     0.450115
# ZN       0.404608
# DIS      0.368813
# B        0.364928
# Name: MV, dtype: float64

# %% [markdown]
# On voit que la plus forte corrélation concerne le pourcentage de population pauvre du quartier
# Par contre, le taux de criminalité ou la distance aux principaux centres d'emploi sont assez peu corrélés

# %% [markdown]
# ## Graphiques avancés

# %% [markdown]
# **Seaborn** est une librairie de visualisation statistique avancée

# %%
import seaborn as sns

# %% [markdown]
# Visualisation des corrélations avec une "carte de températures"

# %%
plt.figure(figsize=(12,12))
sns.heatmap(bos.corr())

# %% [markdown]
# On peut aussi regrouper les paramètres par *clusters* classés par proximité :

# %%
sns.clustermap(bos.corr())

# %% [markdown]
# Seaborn peut afficher tous les nuages de points par paire de paramètres :

# %%
sns.pairplot(bos)

# %% [raw]
# On peut tracer une estimation de la densité de probabilité d'une variable :

# %%
sns.distplot(bos.MV)

# %% [markdown]
# *Pour plus de détails sur l'estimation de densité avec des noyaux de convolution, on pourra consulter par exemple :
# https://www.researchgate.net/publication/257199361_Convolution_power_kernels_for_density_estimation*

# %% [markdown]
# Une autre forme de graphique combine l'affichage d'un nuage de points (du type *scatter*) et des histogrammes des paramètres :

# %%
sns.jointplot(bos.LSTAT,bos.MV)

# %% [markdown]
# On peut regrouper les points voisins sous forme d'hexagones, avec une échelle de couleurs fonction de la densité :

# %%
sns.jointplot(bos.LSTAT, bos.MV, kind='hex')

# %% [markdown]
# Pour des valeurs continues, la convolution avec un noyau permet de visualiser une estimation des densités :

# %%
sns.jointplot(bos.LSTAT, bos.MV, kind='kde')

# %% [markdown]
# ** Pour plus de détails, la document seaborn est très intéressante :
# http://seaborn.pydata.org/ **

# %% [markdown]
# # Exercice : Prix des maisons du Comté de King (USA)

# %% [markdown]
# ** Charger le dataset "kc_house_data.csv" et appliquer une démarche similaire à la précédente **

# %% [raw]
# id
# date: Date house was sold(String)
# price: Price of the sold house
# bedrooms: Numer of Bedrooms
# bathrooms: Numer of bathrooms
# sqft_living: Square footage of the living room
# sqrt_log: Square footage of the log
# floors: Total floors in the house
# waterfront: Whether the house has a view a waterfront(1: yes, 0: not)
# view: unknown
# condition: Condition of the house
# grade: unknown
# sqft_above: Square footage of house apart from basement
# sqft_basement: Square footage of the basement
# yr_built: Built year
# yr_renovated: Year when the house was renovated
# zipcode: zipcode of the house
# lat: Latitude coordinate
# long Longitude coordinate
# sqft_living15: Living room area in 2015(implies some renovations)
# sqrt_lot15: Lot area in 2015(implies some renovations)

# %% [markdown]
# # Exercice : Le vieux Fidèle

# %% [markdown]
# Le Old Faithful (« vieux fidèle » en anglais) est un geyser situé dans le parc national de Yellowstone, aux États-Unis. Ce geyser produit l'un des plus grands jets d'eau chaude et de vapeur au monde, avec le Strokkur islandais.
# https://www.youtube.com/watch?v=wE8NDuzt8eg
# https://www.youtube.com/watch?v=X4zA_YPCyHs

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/OldFaithful1948.jpg/1200px-OldFaithful1948.jpg">

# %% [markdown]
# Dans le fichier "faithful.csv", le séparateur est un point-virgule : il faut le préciser
#
# geyser = pd.read_csv('faithful.csv', sep=';')

# %% [markdown]
# ** Que pouvez-vous observer sur la représentation en nuage de points (de type jointplot) ? **

# %% [markdown]
# # Exercice : dites-le avec des fleurs

# %% [markdown]
# Dataset sur les espèces d'iris - prédéfini dans seaborn par exemple

# %%
iris = sns.load_dataset("iris")

# %% [raw]
# sepal_length : longueur du sépale
# sepal_width : largeur du sépale
# petal_length : longueur du pétale
# petal_width : largeur du pétale
# species : espèce (Setosa, Versicolor ou Virginica)

# %%
sns.pairplot(iris, hue="species")

# %%
fg = sns.FacetGrid(iris, hue="species", size=2.5, aspect=2.5, palette="PiYG")
fg.map(sns.kdeplot, "petal_length")
fg.set(xlim=(0, 80));
