# %%
# Directive pour afficher les graphiques dans Jupyter
# %matplotlib inline
# Pandas : librairie de manipulation de données
# NumPy : librairie de calcul scientifique
# MatPlotLib : librairie de visualisation et graphiques
# SeaBorn : librairie de graphiques avancés
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import metrics

# %%
# Lecture des datasets
data = pd.read_csv('reponses.csv')
data_train = pd.read_csv('responses.csv')
data_test = pd.read_csv('responses.csv')
data_train.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock           ...             Age  \
# 0      1.0  5.0   5.0                1.0           ...            20.0
# 1      2.0  3.0   5.0                4.0           ...            19.0
# 2      5.0  3.0   5.0                3.0           ...            20.0
# 3      1.0  2.0   2.0                1.0           ...            22.0
# 4      3.0  5.0   3.0                1.0           ...            20.0
#
#    Height  Weight  Number of siblings  Gender  Left - right handed  \
# 0   163.0    48.0                 1.0  female         right handed
# 1   163.0    58.0                 2.0  female         right handed
# 2   176.0    67.0                 2.0  female         right handed
# 3   172.0    59.0                 1.0  female         right handed
# 4   170.0    59.0                 1.0  female         right handed
#
#                  Education  Only child  Village - town  House - block of flats
# 0  college/bachelor degree          no         village          block of flats
# 1  college/bachelor degree          no            city          block of flats
# 2         secondary school          no            city          block of flats
# 3  college/bachelor degree         yes            city          house/bungalow
# 4         secondary school          no         village          house/bungalow
#
# [5 rows x 150 columns]

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Columns: 150 entries, Music to House - block of flats
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB

# %%
correlations = data_train.corr()
print(correlations['Happiness in life'].sort_values(ascending=False))
# Out:
# Happiness in life                 1.000000
# Energy levels                     0.440593
# Number of friends                 0.320939
# Personality                       0.304279
# Interests or hobbies              0.236037
# Dreams                            0.210415
# Fun with friends                  0.197328
# New environment                   0.192686
# Socializing                       0.163988
# Reliability                       0.144018
# Economy Management                0.143627
# Active sport                      0.139799
# Spending on healthy eating        0.135244
# Prioritising workload             0.130482
# Cars                              0.130159
# Knowing the right people          0.128942
# Healthy eating                    0.128589
# Entertainment spending            0.126130
# Assertiveness                     0.122393
# Parents' advice                   0.121722
# Dance                             0.120707
# Reggae, Ska                       0.118159
# Physics                           0.115286
# Adrenaline sports                 0.106142
# Mathematics                       0.103518
# Achievements                      0.103134
# Hiphop, Rap                       0.103061
# Children                          0.100709
# Geography                         0.097561
# Latino                            0.097277
#                                     ...
# Spiders                          -0.031738
# Reading                          -0.035212
# Metal or Hardrock                -0.039659
# Dangerous dogs                   -0.040052
# Responding to a serious letter   -0.043660
# Loss of interest                 -0.050056
# Thriller                         -0.052231
# Rock                             -0.060355
# Flying                           -0.061711
# Alternative                      -0.063116
# Horror                           -0.066348
# Writing                          -0.067719
# Sci-fi                           -0.068996
# Darkness                         -0.069498
# Hypochondria                     -0.075140
# Heights                          -0.081425
# Unpopularity                     -0.092153
# Ageing                           -0.098478
# Getting angry                    -0.108437
# Criminal damage                  -0.111370
# Getting up                       -0.114352
# Eating to survive                -0.116020
# Self-criticism                   -0.118271
# Life struggles                   -0.127577
# Public speaking                  -0.141931
# Fake                             -0.149493
# Fear of public speaking          -0.180929
# Mood swings                      -0.238388
# Changing the past                -0.352469
# Loneliness                       -0.437061
# Name: Happiness in life, Length: 139, dtype: float64

# %%
# Importation de la librairie "neural networks" de sklearn
from sklearn.neural_network import MLPClassifier

# %%
# Création d'un réseau dense avec 2 couches cachées de 5 et 3 neurones
mlp =  MLPClassifier(hidden_layer_sizes=(5,3))

# %%
mlp.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-127d8dda6af2> in <module>()
# ----> 1 mlp.fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined
